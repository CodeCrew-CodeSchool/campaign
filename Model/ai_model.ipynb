# %%
import pandas as pd
import nltk
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction

nltk.download('punkt')
nltk.download('punkt_tab')

filename = 'email_dataset.csv'
df = pd.read_csv(filename)
df.columns = df.columns.str.strip()

# Preview data
print("Columns:", df.columns)
print("First few rows:")
print(df.head())

# Generate full email
def generate_full_email(dataframe):
    sample = dataframe.sample(1).iloc[0]
    subject = sample['Subject']
    description = sample['Description']
    body = sample['Body']
    closing = sample['Closing']
    email_content = (
        f"{subject} {description} {body} {closing}"
    )
    return email_content

# BLEU score list
bleu_scores = []

# Evaluate 15 samples
num_samples = 15
for i in range(num_samples):
    # Sample reference email
    reference = generate_full_email(df)
    # Generate new email
    generated = generate_full_email(df)

    # Tokenize
    reference_tokens = nltk.word_tokenize(reference)
    generated_tokens = nltk.word_tokenize(generated)

    # Calculate BLEU
    smooth_fn = SmoothingFunction().method1
    score = sentence_bleu(
        [reference_tokens], generated_tokens, smoothing_function=smooth_fn
    )
    bleu_scores.append(score)
    print(f"Sample {i+1}:\nReference:\n{reference}\n")
    print(f"Generated:\n{generated}\n")
    print(f"BLEU score: {score:.4f}\n{'-'*50}")

# Compute and display average BLEU score
avg_bleu = sum(bleu_scores) / len(bleu_scores)
print(f"\nAverage BLEU score over {num_samples} samples: {avg_bleu:.4f}")
# Out:
# Columns: Index(['Subject', 'Body', 'Description', 'Closing'], dtype='object')
# First few rows:
#                            Subject  \
# 0       Boost Your Business Today!
# 1  Save Big on Your Next Purchase!
# 2         Upgrade Your Tech Setup!
# 3                Join Our Webinar!
# 4          Exclusive Offer Inside!
#
#                                                 Body  \
# 0  Hi there, our innovative solutions can help yo...
# 1  Hello! Don't miss out on our exclusive discoun...
# 2  Dear Customer, upgrade to the latest technolog...
# 3  Hi! Join our upcoming webinar to learn about t...
# 4  Greetings! Unlock exclusive deals tailored jus...
#
#                                          Description  \
# 0  An engaging email encouraging business growth ...
# 1  Promotional email highlighting discounts and u...
# 2  Encourages tech upgrades with a focus on stayi...
# 3  Invitation to an informative webinar with regi...
# 4  Personalized promotional offer with a sense of...
#
#                             Closing
# 0  Best regards,\nYour Company Team
# 1           Cheers,\nThe Sales Team
# 2            Sincerely,\nTech Store
# 3                 Best,\nEvent Team
# 4         Thanks,\nCustomer Support
# Sample 1:
# Reference:
# Join the Green Movement! Renewable energy promotion. Hello! Switch to renewable energy solutions and save on bills. Contact us for details! Go green,
# Energy Solutions
#
# Generated:
# Get Ready for Back to School! Back-to-school promotion. Hi! Find everything you need for a successful school year. Shop our back-to-school collection! Good luck,
# School Supplies Team
#
# BLEU score: 0.0174
# --------------------------------------------------
# Sample 2:
# Reference:
# Healthy Living Starts Here! Health product promotion. Hello! Discover our health and wellness products to help you live better. Shop now and feel great! Stay healthy,
# Wellness Team
#
# Generated:
# Join Our Loyalty Program! Incentivizing customer loyalty. Hello! Sign up for our loyalty program to earn rewards every time you shop. Start saving today! Thanks,
# Rewards Team
#
# BLEU score: 0.0375
# --------------------------------------------------
# Sample 3:
# Reference:
# Unleash Your Creativity! Arts & crafts promotion. Hello! Explore our creative tools and start your next art project today. Shop now! Create something beautiful,
# Art Supplies
#
# Generated:
# Discover Our Services! Service introduction with a call to action. Hi! Learn how our services can help streamline your business operations. Contact us today for a free consultation. Regards,
# Service Team
#
# BLEU score: 0.0084
# --------------------------------------------------
# Sample 4:
# Reference:
# Limited Time Offer! Urgent promotional campaign. Hello! Take advantage of our limited-time offer and save on your favorite items. Hurry before it's gone! Sincerely,
# Marketing Team
#
# Generated:
# Bring Your Ideas to Life! Creative software promotion. Hello! Use our creative software tools to turn your ideas into reality. Try free today! Create now,
# Software Company
#
# BLEU score: 0.0368
# --------------------------------------------------
# Sample 5:
# Reference:
# Your Dream Wedding Awaits! Wedding planning promotion. Hi! Plan your perfect wedding with our expert services. Contact us today! Say I do,
# Wedding Services
#
# Generated:
# Get Fit at Home! Fitness equipment promotion. Hi! Achieve your fitness goals with our home workout equipment. Shop now for exclusive discounts. Stay strong,
# Fitness Co.
#
# BLEU score: 0.0950
# --------------------------------------------------
# Sample 6:
# Reference:
# Exclusive Offer Inside! Personalized promotional offer with a sense of exclusivity. Greetings! Unlock exclusive deals tailored just for you. Don't miss this opportunity to save on your favorite products. Thanks,
# Customer Support
#
# Generated:
# Get Ready for Summer! Seasonal promotion. Hi! Summer is coming. Prepare with our special summer collection and enjoy exclusive discounts. Best,
# Summer Collection Team
#
# BLEU score: 0.0080
# --------------------------------------------------
# Sample 7:
# Reference:
# Boost Your Social Media Presence! Digital marketing promotion. Hello! Grow your brand with our social media marketing services. Contact us today! Cheers,
# Marketing Team
#
# Generated:
# Enjoy Delicious Meals! Food delivery promotion. Hello! Try our chef-curated meal kits and cook like a pro at home. Order now! Bon appétit,
# Meal Kits
#
# BLEU score: 0.0920
# --------------------------------------------------
# Sample 8:
# Reference:
# Join Our Community! Membership promotion. Hello! Become a member of our exclusive community and enjoy special benefits. Sign up today! Join us,
# Community Team
#
# Generated:
# Your Dream Home Awaits! Real estate marketing email. Hello! Find your perfect home with our expert real estate services. Browse listings now! Warm regards,
# Real Estate Team
#
# BLEU score: 0.0368
# --------------------------------------------------
# Sample 9:
# Reference:
# Improve Your Skills! Educational course promotion. Hello! Enroll in our online courses to advance your career. Sign up today and start learning! Best,
# Education Team
#
# Generated:
# Discover Eco-Friendly Products! Sustainable product promotion. Hi! Go green with our eco-friendly product range. Shop now and make a difference! Together for Earth,
# Eco Store
#
# BLEU score: 0.0186
# --------------------------------------------------
# Sample 10:
# Reference:
# Experience Luxury Living! Luxury property marketing. Hello! Discover our luxury real estate options. Schedule a tour today! Luxury awaits,
# Real Estate
#
# Generated:
# Discover Our Services! Service introduction with a call to action. Hi! Learn how our services can help streamline your business operations. Contact us today for a free consultation. Regards,
# Service Team
#
# BLEU score: 0.0087
# --------------------------------------------------
# Sample 11:
# Reference:
# Boost Your Social Media Presence! Digital marketing promotion. Hello! Grow your brand with our social media marketing services. Contact us today! Cheers,
# Marketing Team
#
# Generated:
# Save on Your Next Vacation! Travel promotion. Hi! Explore exciting travel deals and plan your dream vacation today. Book now and save! Adventure awaits,
# Travel Agency
#
# BLEU score: 0.0184
# --------------------------------------------------
# Sample 12:
# Reference:
# Stay Stylish All Year! Seasonal fashion promotion. Hi! Discover our seasonal fashion collections and update your wardrobe. Shop today! Stay trendy,
# Fashion Store
#
# Generated:
# Stay Stylish All Year! Seasonal fashion promotion. Hi! Discover our seasonal fashion collections and update your wardrobe. Shop today! Stay trendy,
# Fashion Store
#
# BLEU score: 1.0000
# --------------------------------------------------
# Sample 13:
# Reference:
# Get Fit at Home! Fitness equipment promotion. Hi! Achieve your fitness goals with our home workout equipment. Shop now for exclusive discounts. Stay strong,
# Fitness Co.
#
# Generated:
# Your Perfect Fit Awaits! Fashion styling service. Hello! Find the perfect outfit with our personalized styling service. Shop today! Stay stylish,
# Fashion Service
#
# BLEU score: 0.0212
# --------------------------------------------------
# Sample 14:
# Reference:
# Discover Eco-Friendly Products! Sustainable product promotion. Hi! Go green with our eco-friendly product range. Shop now and make a difference! Together for Earth,
# Eco Store
#
# Generated:
# Improve Your Skills! Educational course promotion. Hello! Enroll in our online courses to advance your career. Sign up today and start learning! Best,
# Education Team
#
# BLEU score: 0.0186
# --------------------------------------------------
# Sample 15:
# Reference:
# Transform Your Workspace! Office furniture promotion. Hi! Create a more productive workspace with our ergonomic furniture. Shop the collection today! Sincerely,
# Furniture Co.
#
# Generated:
# Save Big on Your Next Purchase! Promotional email highlighting discounts and urgency. Hello! Don't miss out on our exclusive discounts available only for a limited time. Shop now and save big! Cheers,
# The Sales Team
#
# BLEU score: 0.0139
# --------------------------------------------------
#
# Average BLEU score over 15 samples: 0.0954
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
